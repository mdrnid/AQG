# %%
# from typing_extensions import TypedDict
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage,BaseMessage,  RemoveMessage
# from langgraph.checkpoint.memory import InMemorySaver

import os
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()

# print("openAi version : ", OpenAI._version_)

llm_openrouter = ChatOpenAI(
    model=os.getenv("OPENROUTER_MODEL"),
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    seed= 365,
    temperature= 0 ,
    max_completion_tokens= 100
)

# Test simple completion
print("🧪 Testing gemini connection...")

try:
    message = HumanMessage(content="Please write a short fairy tale. Keep it short.")

    response = llm_openrouter.invoke([message])

    print("📖 Fairy Tale:")
    print(response.content)
    print(f"\n📊 Tokens: {response.response_metadata.get('token_usage', 'N/A')}")

    print(f"\n✅ Koneksi berhasil!")

except Exception as e:
    print(f"\n❌ Error: {e}")
    print("\nTroubleshooting:")
    print("1. Cek API key di file .env")
    print("2. Pastikan internet connection aktif")
    print("3. Verify API key valid di dashboard Z.AI")
# Out:
# 🧪 Testing gemini connection...
#
# ❌ Error: Error code: 400 - [{'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}]
#
# Troubleshooting:
# 1. Cek API key di file .env
# 2. Pastikan internet connection aktif
# 3. Verify API key valid di dashboard Z.AI

# %%
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# Load environment variables
load_dotenv()

# Inisialisasi model Gemini (rekomendasi resmi)
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",           # atau "gemini-1.5-pro", "gemini-1.5-flash", dll.
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0,
    # max_tokens=100,
    # top_p=0.95,                           # parameter Gemini-specific (opsional)
    # safety_settings="BLOCK_MEDIUM_AND_ABOVE"  # contoh pengaturan safety
)

# Test koneksi
print("🧪 Testing Gemini connection via langchain-google-genai...")

try:
    message = HumanMessage(content="Please write a short fairy tale. Keep it short.")
    response = llm.invoke([message])
    
    print("📖 Fairy Tale:")
    print(response.content)
    print(f"\n📊 Tokens: {response.response_metadata.get('token_usage', 'N/A')}")
    print("\n✅ Koneksi berhasil! Menggunakan integrasi resmi LangChain.")
    
except Exception as e:
    print(f"\n❌ Error: {e}")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 🧪 Testing Gemini connection via langchain-google-genai...
# 📖 Fairy Tale:
# Elara lived in a cottage nestled beside a whispering woods. She was a quiet girl, whose greatest joy was her garden, especially a single, rare moonpetal flower that glowed faintly at dusk.
#
# One morning, Elara found her moonpetal wilting, its silvery light dimming. Her heart ached. Suddenly, a tiny, iridescent hummingbird, no bigger than her thumb, zipped before her.
#
# "The moonpetal needs a tear from the Crystal Spring," it chirped, its voice like tiny bells. "But the spring lies deep within the Shadowed Glade, guarded by the Grumpy Gnome."
#
# Elara was timid, but her love for the moonpetal gave her courage. She thanked the hummingbird and, with a deep breath, stepped into the woods. The trees grew tall and dark, but she pressed on, until she found the Grumpy Gnome blocking a path.
#
# "No one passes!" he grumbled, his beard bristling.
#
# "Please, sir," Elara said softly, "my moonpetal is dying. I only need a single tear from the Crystal Spring."
#
# The gnome looked at her, surprised by her gentle plea. He saw the genuine sadness in her eyes. "Very well," he sighed, stepping aside. "But be quick."
#
# Elara hurried to the spring, collected a shimmering drop, and rushed back. A single tear on the moonpetal, and it unfurled, glowing brighter than ever. Elara smiled, a brave, happy smile. She had saved her flower, and learned that even the smallest heart can hold the greatest courage.
#
# 📊 Tokens: N/A
#
# ✅ Koneksi berhasil! Menggunakan integrasi resmi LangChain.
